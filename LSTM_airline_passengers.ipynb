# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv('airline-passengers-dataset.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# %%
dataset = dataset.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.69)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 99 45

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX
# Out:
# array([[0.01544401],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984557],
#        [0.08494207],
#        [0.08494207],
#        [0.06177607],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123553],
#        [0.04247104],
#        [0.07142857],
#        [0.05984557],
#        [0.04054055],
#        [0.08687258],
#        [0.12741312],
#        [0.12741312],
#        [0.10424709],
#        [0.05598456],
#        [0.01930502],
#        [0.06949806],
#        [0.07915059],
#        [0.08880308],
#        [0.14285713],
#        [0.11389962],
#        [0.13127413],
#        [0.14285713],
#        [0.18339768],
#        [0.18339768],
#        [0.15444016],
#        [0.11196911],
#        [0.08108109],
#        [0.1196911 ],
#        [0.12934363],
#        [0.14671814],
#        [0.17181468],
#        [0.14864865],
#        [0.15250966],
#        [0.22007722],
#        [0.24324325],
#        [0.26640925],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374519],
#        [0.17760617],
#        [0.17760617],
#        [0.25482625],
#        [0.25289574],
#        [0.24131274],
#        [0.26833975],
#        [0.3088803 ],
#        [0.32432434],
#        [0.25675675],
#        [0.20656371],
#        [0.14671814],
#        [0.18725869],
#        [0.19305018],
#        [0.16216215],
#        [0.25289574],
#        [0.23745173],
#        [0.25096524],
#        [0.3088803 ],
#        [0.38223937],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.1911197 ],
#        [0.24131274],
#        [0.26640925],
#        [0.24903473],
#        [0.31467178],
#        [0.3185328 ],
#        [0.32046333],
#        [0.4073359 ],
#        [0.5019305 ],
#        [0.46911195],
#        [0.40154442],
#        [0.32818535],
#        [0.25675675],
#        [0.3359073 ],
#        [0.34749034],
#        [0.33397684],
#        [0.41119692],
#        [0.4034749 ],
#        [0.4131274 ],
#        [0.52123547],
#        [0.5965251 ],
#        [0.58108103],
#        [0.484556  ],
#        [0.3899614 ],
#        [0.3223938 ],
#        [0.3899614 ],
#        [0.4073359 ]], dtype=float32)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics='accuracy')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 97/97 - 2s - loss: 0.0452 - accuracy: 0.0103 - 2s/epoch - 20ms/step
# Epoch 2/100
# 97/97 - 0s - loss: 0.0211 - accuracy: 0.0103 - 204ms/epoch - 2ms/step
# Epoch 3/100
# 97/97 - 0s - loss: 0.0158 - accuracy: 0.0103 - 194ms/epoch - 2ms/step
# Epoch 4/100
# 97/97 - 0s - loss: 0.0144 - accuracy: 0.0103 - 202ms/epoch - 2ms/step
# Epoch 5/100
# 97/97 - 0s - loss: 0.0135 - accuracy: 0.0103 - 198ms/epoch - 2ms/step
# Epoch 6/100
# 97/97 - 0s - loss: 0.0124 - accuracy: 0.0103 - 184ms/epoch - 2ms/step
# Epoch 7/100
# 97/97 - 0s - loss: 0.0114 - accuracy: 0.0103 - 200ms/epoch - 2ms/step
# Epoch 8/100
# 97/97 - 0s - loss: 0.0104 - accuracy: 0.0103 - 196ms/epoch - 2ms/step
# Epoch 9/100
# 97/97 - 0s - loss: 0.0093 - accuracy: 0.0103 - 207ms/epoch - 2ms/step
# Epoch 10/100
# 97/97 - 0s - loss: 0.0083 - accuracy: 0.0103 - 186ms/epoch - 2ms/step
# Epoch 11/100
# 97/97 - 0s - loss: 0.0073 - accuracy: 0.0103 - 182ms/epoch - 2ms/step
# Epoch 12/100
# 97/97 - 0s - loss: 0.0064 - accuracy: 0.0103 - 215ms/epoch - 2ms/step
# Epoch 13/100
# 97/97 - 0s - loss: 0.0056 - accuracy: 0.0103 - 184ms/epoch - 2ms/step
# Epoch 14/100
# 97/97 - 0s - loss: 0.0048 - accuracy: 0.0103 - 182ms/epoch - 2ms/step
# Epoch 15/100
# 97/97 - 0s - loss: 0.0042 - accuracy: 0.0103 - 194ms/epoch - 2ms/step
# Epoch 16/100
# 97/97 - 0s - loss: 0.0037 - accuracy: 0.0103 - 176ms/epoch - 2ms/step
# Epoch 17/100
# 97/97 - 0s - loss: 0.0032 - accuracy: 0.0103 - 189ms/epoch - 2ms/step
# Epoch 18/100
# 97/97 - 0s - loss: 0.0028 - accuracy: 0.0103 - 199ms/epoch - 2ms/step
# Epoch 19/100
# 97/97 - 0s - loss: 0.0025 - accuracy: 0.0103 - 193ms/epoch - 2ms/step
# Epoch 20/100
# 97/97 - 0s - loss: 0.0024 - accuracy: 0.0103 - 179ms/epoch - 2ms/step
# Epoch 21/100
# 97/97 - 0s - loss: 0.0022 - accuracy: 0.0103 - 205ms/epoch - 2ms/step
# Epoch 22/100
# 97/97 - 0s - loss: 0.0022 - accuracy: 0.0103 - 200ms/epoch - 2ms/step
# Epoch 23/100
# 97/97 - 0s - loss: 0.0022 - accuracy: 0.0103 - 216ms/epoch - 2ms/step
# Epoch 24/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 187ms/epoch - 2ms/step
# Epoch 25/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 202ms/epoch - 2ms/step
# Epoch 26/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 189ms/epoch - 2ms/step
# Epoch 27/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 201ms/epoch - 2ms/step
# Epoch 28/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 226ms/epoch - 2ms/step
# Epoch 29/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 203ms/epoch - 2ms/step
# Epoch 30/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 192ms/epoch - 2ms/step
# Epoch 31/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 187ms/epoch - 2ms/step
# Epoch 32/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 191ms/epoch - 2ms/step
# Epoch 33/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 289ms/epoch - 3ms/step
# Epoch 34/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 289ms/epoch - 3ms/step
# Epoch 35/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 280ms/epoch - 3ms/step
# Epoch 36/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 279ms/epoch - 3ms/step
# Epoch 37/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 273ms/epoch - 3ms/step
# Epoch 38/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 304ms/epoch - 3ms/step
# Epoch 39/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 314ms/epoch - 3ms/step
# Epoch 40/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 301ms/epoch - 3ms/step
# Epoch 41/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 265ms/epoch - 3ms/step
# Epoch 42/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 174ms/epoch - 2ms/step
# Epoch 43/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 44/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 183ms/epoch - 2ms/step
# Epoch 45/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 177ms/epoch - 2ms/step
# Epoch 46/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 183ms/epoch - 2ms/step
# Epoch 47/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 183ms/epoch - 2ms/step
# Epoch 48/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 179ms/epoch - 2ms/step
# Epoch 49/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 178ms/epoch - 2ms/step
# Epoch 50/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 178ms/epoch - 2ms/step
# Epoch 51/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 170ms/epoch - 2ms/step
# Epoch 52/100
# 97/97 - 0s - loss: 0.0022 - accuracy: 0.0103 - 185ms/epoch - 2ms/step
# Epoch 53/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 174ms/epoch - 2ms/step
# Epoch 54/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 189ms/epoch - 2ms/step
# Epoch 55/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 192ms/epoch - 2ms/step
# Epoch 56/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 185ms/epoch - 2ms/step
# Epoch 57/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 182ms/epoch - 2ms/step
# Epoch 58/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 59/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 186ms/epoch - 2ms/step
# Epoch 60/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 186ms/epoch - 2ms/step
# Epoch 61/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 183ms/epoch - 2ms/step
# Epoch 62/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 63/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 178ms/epoch - 2ms/step
# Epoch 64/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 179ms/epoch - 2ms/step
# Epoch 65/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 192ms/epoch - 2ms/step
# Epoch 66/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 187ms/epoch - 2ms/step
# Epoch 67/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 179ms/epoch - 2ms/step
# Epoch 68/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 186ms/epoch - 2ms/step
# Epoch 69/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 70/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 182ms/epoch - 2ms/step
# Epoch 71/100
# 97/97 - 0s - loss: 0.0018 - accuracy: 0.0103 - 175ms/epoch - 2ms/step
# Epoch 72/100
# 97/97 - 0s - loss: 0.0022 - accuracy: 0.0103 - 184ms/epoch - 2ms/step
# Epoch 73/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 178ms/epoch - 2ms/step
# Epoch 74/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 183ms/epoch - 2ms/step
# Epoch 75/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 177ms/epoch - 2ms/step
# Epoch 76/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 177ms/epoch - 2ms/step
# Epoch 77/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 185ms/epoch - 2ms/step
# Epoch 78/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 179ms/epoch - 2ms/step
# Epoch 79/100
# 97/97 - 0s - loss: 0.0019 - accuracy: 0.0103 - 183ms/epoch - 2ms/step
# Epoch 80/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 81/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 179ms/epoch - 2ms/step
# Epoch 82/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 177ms/epoch - 2ms/step
# Epoch 83/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 184ms/epoch - 2ms/step
# Epoch 84/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 182ms/epoch - 2ms/step
# Epoch 85/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 174ms/epoch - 2ms/step
# Epoch 86/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 87/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 175ms/epoch - 2ms/step
# Epoch 88/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 189ms/epoch - 2ms/step
# Epoch 89/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 182ms/epoch - 2ms/step
# Epoch 90/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 174ms/epoch - 2ms/step
# Epoch 91/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 177ms/epoch - 2ms/step
# Epoch 92/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 174ms/epoch - 2ms/step
# Epoch 93/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 181ms/epoch - 2ms/step
# Epoch 94/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 177ms/epoch - 2ms/step
# Epoch 95/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 196ms/epoch - 2ms/step
# Epoch 96/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 257ms/epoch - 3ms/step
# Epoch 97/100
# 97/97 - 0s - loss: 0.0019 - accuracy: 0.0103 - 255ms/epoch - 3ms/step
# Epoch 98/100
# 97/97 - 0s - loss: 0.0021 - accuracy: 0.0103 - 270ms/epoch - 3ms/step
# Epoch 99/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 272ms/epoch - 3ms/step
# Epoch 100/100
# 97/97 - 0s - loss: 0.0020 - accuracy: 0.0103 - 287ms/epoch - 3ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 4/4 [==============================] - 1s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# Train Score: 23.22 RMSE
# Test Score: 47.80 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
